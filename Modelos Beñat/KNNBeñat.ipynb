# %% [markdown]
# #Modelos KNN Beñat

# %%
import pandas as pd
import numpy as np

# %%
df_train = pd.read_csv("../data_train.csv")
df_test = pd.read_csv("../data_test.csv")

# %%
X_train = df_train.drop(columns=['winner'])
y_train = df_train['winner']

X_test = df_test.drop(columns=['winner'])
y_test = df_test['winner']

# %% [markdown]
# Configuramos el Grid Search para evaluar distintos modelos KNN con distintos hiperparámetros. Evaluamos cada modelo mediante las métricas de accuracy, precision, recall y f1-score. Para obtener más detalles, consultar la memoria del proyecto.

# %%
import time
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import ParameterGrid
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# Escalar los datos
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Definir una grilla más extensa
param_grid = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

results = []

# Ejecutar todas las combinaciones
for i, params in enumerate(ParameterGrid(param_grid)):
    print(f"\n🔍 Combinación {i+1}/{len(list(ParameterGrid(param_grid)))}: {params}")

    model = KNeighborsClassifier(**params)

    # Entrenamiento
    start_train = time.time()
    model.fit(X_train_scaled, y_train)
    end_train = time.time()
    train_time = end_train - start_train

    # Predicción
    start_eval = time.time()
    y_pred = model.predict(X_test_scaled)
    end_eval = time.time()
    eval_time = end_eval - start_eval

    # Métricas
    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred, zero_division=0)
    rec = recall_score(y_test, y_pred, zero_division=0)
    f1 = f1_score(y_test, y_pred, zero_division=0)

    # Guardar resultados
    results.append({
        'n_neighbors': params['n_neighbors'],
        'weights': params['weights'],
        'metric': params['metric'],
        'accuracy': acc,
        'precision': prec,
        'recall': rec,
        'f1_score': f1,
        'train_time': train_time,
        'eval_time': eval_time
    })

    # Imprimir resultados parciales
    print(f"Accuracy:  {acc:.4f}")
    print(f"Precision: {prec:.4f}")
    print(f"Recall:    {rec:.4f}")
    print(f"F1 Score:  {f1:.4f}")
    print(f"Tiempo entrenamiento: {train_time:.2f}s | Tiempo evaluación: {eval_time:.4f}s")

# Mostrar resumen ordenado
df_results = pd.DataFrame(results)
df_results = df_results.sort_values(by='f1_score', ascending=False)

print("\n=== 🏁 RESUMEN FINAL (ordenado por F1 Score) ===")
print(df_results[['n_neighbors', 'weights', 'metric', 'f1_score', 'accuracy', 'train_time']].to_string(index=False))
# Out:
# 🔍 Combinación 1/16: {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}
# Accuracy:  0.5996
# Precision: 0.5988
# Recall:    0.5990
# F1 Score:  0.5989
# Tiempo entrenamiento: 0.05s | Tiempo evaluación: 37.2424s
#
# 🔍 Combinación 2/16: {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'distance'}
# Accuracy:  0.5998
# Precision: 0.5990
# Recall:    0.5991
# F1 Score:  0.5991
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 37.9627s
#
# 🔍 Combinación 3/16: {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'uniform'}
# Accuracy:  0.6129
# Precision: 0.6119
# Recall:    0.6135
# F1 Score:  0.6127
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 37.7435s
#
# 🔍 Combinación 4/16: {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'distance'}
# Accuracy:  0.6131
# Precision: 0.6121
# Recall:    0.6137
# F1 Score:  0.6129
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 38.1126s
#
# 🔍 Combinación 5/16: {'metric': 'euclidean', 'n_neighbors': 7, 'weights': 'uniform'}
# Accuracy:  0.6200
# Precision: 0.6200
# Recall:    0.6159
# F1 Score:  0.6179
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 37.9458s
#
# 🔍 Combinación 6/16: {'metric': 'euclidean', 'n_neighbors': 7, 'weights': 'distance'}
# Accuracy:  0.6200
# Precision: 0.6201
# Recall:    0.6158
# F1 Score:  0.6179
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 37.2974s
#
# 🔍 Combinación 7/16: {'metric': 'euclidean', 'n_neighbors': 9, 'weights': 'uniform'}
# Accuracy:  0.6267
# Precision: 0.6260
# Recall:    0.6260
# F1 Score:  0.6260
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 37.0652s
#
# 🔍 Combinación 8/16: {'metric': 'euclidean', 'n_neighbors': 9, 'weights': 'distance'}
# Accuracy:  0.6270
# Precision: 0.6263
# Recall:    0.6262
# F1 Score:  0.6262
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 37.0330s
#
# 🔍 Combinación 9/16: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'uniform'}
# Accuracy:  0.6022
# Precision: 0.6002
# Recall:    0.6075
# F1 Score:  0.6039
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 40.9355s
#
# 🔍 Combinación 10/16: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'distance'}
# Accuracy:  0.6021
# Precision: 0.6001
# Recall:    0.6076
# F1 Score:  0.6038
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 40.6319s
#
# 🔍 Combinación 11/16: {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'uniform'}
# Accuracy:  0.6156
# Precision: 0.6149
# Recall:    0.6149
# F1 Score:  0.6149
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 40.8955s
#
# 🔍 Combinación 12/16: {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}
# Accuracy:  0.6157
# Precision: 0.6149
# Recall:    0.6154
# F1 Score:  0.6151
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 39.7720s
#
# 🔍 Combinación 13/16: {'metric': 'manhattan', 'n_neighbors': 7, 'weights': 'uniform'}
# Accuracy:  0.6186
# Precision: 0.6183
# Recall:    0.6164
# F1 Score:  0.6173
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 41.1920s
#
# 🔍 Combinación 14/16: {'metric': 'manhattan', 'n_neighbors': 7, 'weights': 'distance'}
# Accuracy:  0.6186
# Precision: 0.6182
# Recall:    0.6165
# F1 Score:  0.6174
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 38.6544s
#
# 🔍 Combinación 15/16: {'metric': 'manhattan', 'n_neighbors': 9, 'weights': 'uniform'}
# Accuracy:  0.6275
# Precision: 0.6265
# Recall:    0.6278
# F1 Score:  0.6272
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 40.1572s
#
# 🔍 Combinación 16/16: {'metric': 'manhattan', 'n_neighbors': 9, 'weights': 'distance'}
# Accuracy:  0.6272
# Precision: 0.6261
# Recall:    0.6278
# F1 Score:  0.6270
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 38.1497s
#
# === 🏁 RESUMEN FINAL (ordenado por F1 Score) ===
#  n_neighbors  weights    metric  f1_score  accuracy  train_time
#            9  uniform manhattan  0.627154  0.627471    0.036462
#            9 distance manhattan  0.626976  0.627188    0.035849
#            9 distance euclidean  0.626226  0.626951    0.036436
#            9  uniform euclidean  0.626007  0.626715    0.039180
#            7  uniform euclidean  0.617945  0.619951    0.038963
#            7 distance euclidean  0.617909  0.619951    0.037617
#            7 distance manhattan  0.617378  0.618626    0.036735
#            7  uniform manhattan  0.617341  0.618626    0.037393
#            5 distance manhattan  0.615130  0.615694    0.036268
#            5  uniform manhattan  0.614889  0.615599    0.036798
#            5 distance euclidean  0.612873  0.613092    0.037507
#            5  uniform euclidean  0.612683  0.612903    0.035628
#            3  uniform manhattan  0.603862  0.602214    0.036625
#            3 distance manhattan  0.603814  0.602072    0.036113
#            3 distance euclidean  0.599062  0.599801    0.035819
#            3  uniform euclidean  0.598910  0.599612    0.050023

# %% [markdown]
# Se ha hecho una segunda búsqueda en rejilla con otros hiperparámetros

# %%
import time
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import ParameterGrid
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# Escalar los datos
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Definir una grilla más extensa
param_grid = {
    'n_neighbors': [101, 301, 601, 1001],
    'weights': ['distance', 'uniform'],
    'metric': ['euclidean', 'manhattan']
}

results = []

# Ejecutar todas las combinaciones
for i, params in enumerate(ParameterGrid(param_grid)):
    print(f"\n🔍 Combinación {i+1}/{len(list(ParameterGrid(param_grid)))}: {params}")

    model = KNeighborsClassifier(**params)

    # Entrenamiento
    start_train = time.time()
    model.fit(X_train_scaled, y_train)
    end_train = time.time()
    train_time = end_train - start_train

    # Predicción
    start_eval = time.time()
    y_pred = model.predict(X_test_scaled)
    end_eval = time.time()
    eval_time = end_eval - start_eval

    # Métricas
    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred, zero_division=0)
    rec = recall_score(y_test, y_pred, zero_division=0)
    f1 = f1_score(y_test, y_pred, zero_division=0)

    # Guardar resultados
    results.append({
        'n_neighbors': params['n_neighbors'],
        'weights': params['weights'],
        'metric': params['metric'],
        'accuracy': acc,
        'precision': prec,
        'recall': rec,
        'f1_score': f1,
        'train_time': train_time,
        'eval_time': eval_time
    })

    # Imprimir resultados parciales
    print(f"Accuracy:  {acc:.4f}")
    print(f"Precision: {prec:.4f}")
    print(f"Recall:    {rec:.4f}")
    print(f"F1 Score:  {f1:.4f}")
    print(f"Tiempo entrenamiento: {train_time:.2f}s | Tiempo evaluación: {eval_time:.4f}s")

# Mostrar resumen ordenado
df_results = pd.DataFrame(results)
df_results = df_results.sort_values(by='f1_score', ascending=False)

print("\n=== 🏁 RESUMEN FINAL (ordenado por F1 Score) ===")
print(df_results[['n_neighbors', 'weights', 'metric', 'f1_score', 'accuracy', 'train_time']].to_string(index=False))
# Out:
# 🔍 Combinación 1/16: {'metric': 'euclidean', 'n_neighbors': 101, 'weights': 'distance'}
# Accuracy:  0.6543
# Precision: 0.6533
# Recall:    0.6547
# F1 Score:  0.6540
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 31.0746s
#
# 🔍 Combinación 2/16: {'metric': 'euclidean', 'n_neighbors': 101, 'weights': 'uniform'}
# Accuracy:  0.6543
# Precision: 0.6532
# Recall:    0.6549
# F1 Score:  0.6541
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 31.5359s
#
# 🔍 Combinación 3/16: {'metric': 'euclidean', 'n_neighbors': 301, 'weights': 'distance'}
# Accuracy:  0.6542
# Precision: 0.6523
# Recall:    0.6578
# F1 Score:  0.6550
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 32.5517s
#
# 🔍 Combinación 4/16: {'metric': 'euclidean', 'n_neighbors': 301, 'weights': 'uniform'}
# Accuracy:  0.6544
# Precision: 0.6526
# Recall:    0.6575
# F1 Score:  0.6551
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 32.7438s
#
# 🔍 Combinación 5/16: {'metric': 'euclidean', 'n_neighbors': 601, 'weights': 'distance'}
# Accuracy:  0.6532
# Precision: 0.6517
# Recall:    0.6554
# F1 Score:  0.6536
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 33.7560s
#
# 🔍 Combinación 6/16: {'metric': 'euclidean', 'n_neighbors': 601, 'weights': 'uniform'}
# Accuracy:  0.6526
# Precision: 0.6512
# Recall:    0.6543
# F1 Score:  0.6528
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 33.6105s
#
# 🔍 Combinación 7/16: {'metric': 'euclidean', 'n_neighbors': 1001, 'weights': 'distance'}
# Accuracy:  0.6510
# Precision: 0.6490
# Recall:    0.6547
# F1 Score:  0.6519
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 34.7387s
#
# 🔍 Combinación 8/16: {'metric': 'euclidean', 'n_neighbors': 1001, 'weights': 'uniform'}
# Accuracy:  0.6505
# Precision: 0.6485
# Recall:    0.6544
# F1 Score:  0.6514
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 33.8084s
#
# 🔍 Combinación 9/16: {'metric': 'manhattan', 'n_neighbors': 101, 'weights': 'distance'}
# Accuracy:  0.6526
# Precision: 0.6509
# Recall:    0.6553
# F1 Score:  0.6531
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 36.0089s
#
# 🔍 Combinación 10/16: {'metric': 'manhattan', 'n_neighbors': 101, 'weights': 'uniform'}
# Accuracy:  0.6519
# Precision: 0.6505
# Recall:    0.6537
# F1 Score:  0.6521
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 35.8386s
#
# 🔍 Combinación 11/16: {'metric': 'manhattan', 'n_neighbors': 301, 'weights': 'distance'}
# Accuracy:  0.6535
# Precision: 0.6525
# Recall:    0.6540
# F1 Score:  0.6532
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 35.7535s
#
# 🔍 Combinación 12/16: {'metric': 'manhattan', 'n_neighbors': 301, 'weights': 'uniform'}
# Accuracy:  0.6531
# Precision: 0.6523
# Recall:    0.6530
# F1 Score:  0.6526
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 36.5443s
#
# 🔍 Combinación 13/16: {'metric': 'manhattan', 'n_neighbors': 601, 'weights': 'distance'}
# Accuracy:  0.6519
# Precision: 0.6511
# Recall:    0.6517
# F1 Score:  0.6514
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 35.8916s
#
# 🔍 Combinación 14/16: {'metric': 'manhattan', 'n_neighbors': 601, 'weights': 'uniform'}
# Accuracy:  0.6515
# Precision: 0.6508
# Recall:    0.6511
# F1 Score:  0.6510
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 35.9258s
#
# 🔍 Combinación 15/16: {'metric': 'manhattan', 'n_neighbors': 1001, 'weights': 'distance'}
# Accuracy:  0.6503
# Precision: 0.6492
# Recall:    0.6511
# F1 Score:  0.6502
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 38.7896s
#
# 🔍 Combinación 16/16: {'metric': 'manhattan', 'n_neighbors': 1001, 'weights': 'uniform'}
# Accuracy:  0.6498
# Precision: 0.6488
# Recall:    0.6506
# F1 Score:  0.6497
# Tiempo entrenamiento: 0.04s | Tiempo evaluación: 38.7162s
#
# === 🏁 RESUMEN FINAL (ordenado por F1 Score) ===
#  n_neighbors  weights    metric  f1_score  accuracy  train_time
#          301  uniform euclidean  0.655052  0.654432    0.037350
#          301 distance euclidean  0.654995  0.654195    0.037574
#          101  uniform euclidean  0.654077  0.654290    0.036734
#          101 distance euclidean  0.654012  0.654290    0.037585
#          601 distance euclidean  0.653561  0.653249    0.037137
#          301 distance manhattan  0.653224  0.653486    0.037777
#          101 distance manhattan  0.653096  0.652587    0.036621
#          601  uniform euclidean  0.652768  0.652587    0.039630
#          301  uniform manhattan  0.652648  0.653108    0.038109
#          101  uniform manhattan  0.652106  0.651925    0.036939
#         1001 distance euclidean  0.651852  0.650979    0.037415
#         1001  uniform euclidean  0.651446  0.650506    0.037646
#          601 distance manhattan  0.651414  0.651925    0.037751
#          601  uniform manhattan  0.650969  0.651547    0.037498
#         1001 distance manhattan  0.650168  0.650317    0.037649
#         1001  uniform manhattan  0.649662  0.649844    0.038140
